# %%
from sql_scanner.sql_injection_scanner import SQLInjectionScanner

# %%
if __name__ == "__main__":
    print("check the SQL injection")
    scanner = SQLInjectionScanner()
    test_url = input("enter the website to check sql injection attack: ")
    test_url = test_url+"/product?id="
    
    # Perform a GET scan
    print ("scan the get method")
    scanner.scan_get(test_url)
    

    # Perform a POST scan
    print ("scan the post method")
    test_data = {"input": ""}
    scanner.scan_post(test_url, test_data)
    

    # Perform a blind SQL injection scan
    print ("scan the test url")
    scanner.scan_with_blind_payloads(test_url)
# Out:
# check the SQL injection
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 if __name__ == "__main__":
#       2     print("check the SQL injection")
# ----> 3     scanner = SQLInjectionScanner()
#       4     test_url = input("enter the website to check sql injection attack: ")
#       5     test_url = test_url+"/product?id="
#
# TypeError: SQLInjectionScanner.__init__() missing 1 required positional argument: 'url'
